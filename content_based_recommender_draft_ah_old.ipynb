# %% [markdown]
# ## This notebook:
# - Recommend a course based on the course description
# 1.
#     - Topic modeling on course descriptions
#     - Take a course title (e.g. AAS 103)
#     - Take the course description of this course
#     - Process text of the description
#     - Find the topics of this block of text
#
# 2.
#     - Process text of the descriptions of all other courses
#     - Find the topics of those blocks of text
#
# 3.
#     - Match the topic of the input course and other courses
#     - Compute similarity scores
#     - Rank these scores from high to low
#     - Return the n number of recommendations needed (num_of_rec) by order of similarity
#
# - Need to improve
#
#     - Text processing
#     - Topic modeling (the recommendations are not quite logical yet since the text processing and topic modeling are not quite well-done yet)
#     - Efficiency of the algorithm (slow now)

# %% [markdown]
# ### Paper that helps: https://www.frontiersin.org/articles/10.3389/frai.2020.00042/full

# %%
import pandas as pd
import neattext.functions as nfx

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, linear_kernel, sigmoid_kernel

# %%
# Load our dataset
online = pd.read_csv('assets/original/2021-10-19-MichiganOnline-courses.csv')
f_21 = pd.read_csv('assets/f_21_merge.csv')
w_22 = pd.read_csv('assets/w_22_merge.csv')

# %% [markdown]
# ## Cosine similarity

# %%
def make_recommendation_cos(df, course_title, num_of_rec):
    
    df = df.fillna('').drop_duplicates(subset=['course']).reset_index().drop(columns='index')
    
    # Clean Text
    df['description'] = df['description'].apply(nfx.remove_stopwords)
    df['description'] = df['description'].apply(nfx.remove_special_characters)
    
    # Vectorize our Text
    count_vect = CountVectorizer()
    cv_mat = count_vect.fit_transform(df['description'])
    
    df_cv_words = pd.DataFrame(cv_mat.todense(), columns=count_vect.get_feature_names())
    
    # Cosine Similarity Matrix
    cosine_sim_mat = cosine_similarity(cv_mat)
    
    # Get Course ID/Index
    course_indices = pd.Series(df.index, index=df['course'])

    # ID for title
    idx = course_indices[course_title]
    
    # Course Indice
    # Search inside cosine_sim_mat
    scores = list(enumerate(cosine_sim_mat[idx]))
    
    # Scores
    # Sort Scores
    sorted_scores = sorted(scores, key=lambda x:x[1], reverse=True)
    
    # Recommender
    selected_course_indices = [i[0] for i in sorted_scores[1:]]
    selected_course_scores = [i[1] for i in sorted_scores[1:]]
    
    result = df[df.columns].iloc[selected_course_indices]
    
    rec_df = pd.DataFrame(result)
    
    rec_df['similarity_scores'] = selected_course_scores
    
    return rec_df.head(num_of_rec)

# %% [markdown]
# ## Sigmoid kernel

# %%
def make_recommendation_sk(df, course, num_of_rec):
    
    tfidf = TfidfVectorizer(min_df=3, max_features=None, 
                strip_accents='unicode', analyzer='word', token_pattern=r'\w{1,}',
                ngram_range=(1, 3),
                stop_words='english')

    df = df.fillna('').drop_duplicates(subset=['course']).reset_index().drop(columns='index')

    # Fitting the TF-IDF on the 'description' text
    tfidf_matrix = tfidf.fit_transform(df['description'])

    # Compute the sigmoid kernel
    sig = sigmoid_kernel(tfidf_matrix, tfidf_matrix)

    # Reverse mapping of indices and course titles
    indices = pd.Series(df.index, index=df['course']).drop_duplicates()

    # Get the index corresponding to course title
    idx = indices[course]

    # Get the pairwsie similarity scores 
    sig_scores = list(enumerate(sig[idx]))

    # Sort the courses
    sig_scores = sorted(sig_scores, key=lambda x: x[1], reverse=True)

    # Scores of the n most similar courses
    sig_scores = sig_scores[1:num_of_rec+1]

    # Take the indices
    course_indices = [i[0] for i in sig_scores]

    # Top 10 most similar courses
    rec_df = df[df.columns].iloc[course_indices]
    
    rec_df['sig_scores'] = sig_scores

    return rec_df

# %%
make_recommendation_cos(f_21, 'AAS 103', 10)
# Out:
#       Class Nbr        course       Term                   Session  \
# 2895      37153   MIDEAST 490  Fall 2021  Regular Academic Session
# 3705      11707    PORTUG 101  Fall 2021  Regular Academic Session
# 1789      20075   ENVIRON 405  Fall 2021  Regular Academic Session
# 234       10647  ANTHRCUL 101  Fall 2021  Regular Academic Session
# 2153      11331   HISTORY 260  Fall 2021  Regular Academic Session
# 419       14147  ASIANLAN 115  Fall 2021  Regular Academic Session
# 429       24765  ASIANLAN 185  Fall 2021  Regular Academic Session
# 424       27678  ASIANLAN 145  Fall 2021  Regular Academic Session
# 442       15824  ASIANLAN 305  Fall 2021  Regular Academic Session
# 3711      23618       PPE 400  Fall 2021  Regular Academic Session
#
#                           Acad Group  \
# 2895   Literature, Sci, and the Arts
# 3705   Literature, Sci, and the Arts
# 1789  Environment and Sustainability
# 234    Literature, Sci, and the Arts
# 2153   Literature, Sci, and the Arts
# 419    Literature, Sci, and the Arts
# 429    Literature, Sci, and the Arts
# 424    Literature, Sci, and the Arts
# 442    Literature, Sci, and the Arts
# 3711   Literature, Sci, and the Arts
#
#                                                 Subject          Course Title  \
# 2895        Middle East Studies (MIDEAST) Open Sections         Topics in MES
# 3705                  Portuguese (PORTUG) Open Sections            Elementary
# 1789                Environment (ENVIRON) Open Sections          Urban Sprawl
# 234      Anthropology,Cultural (ANTHRCUL) Open Sections       Intro to Anthro
# 2153                    History (HISTORY) Open Sections           U S to 1865
# 419            Asian Languages (ASIANLAN) Open Sections        1st Yr Hindi I
# 429            Asian Languages (ASIANLAN) Open Sections  First Year Bengali I
# 424            Asian Languages (ASIANLAN) Open Sections      1st Yr Punjabi I
# 442            Asian Languages (ASIANLAN) Open Sections    Inter Spoken Chn I
# 3711  Philosophy, Politics and Economics (PPE) Open ...     Political Economy
#
#                                             description Component       Time  \
# 2895  course aims focus analyzing popular culture me...       SEM    1-230PM
# 3705  PORT101 highly communicative course students s...       REC    10-11AM
# 1789  course investigates political imperatives poli...       LEC  10-1130AM
# 234   course introduces students anthropology subdis...       DIS      4-5PM
# 2153  course analyzes history United States 1865 foc...       DIS      1-2PM
# 419   ASIANLAN 115 beginners course designed student...       REC     9-10AM
# 429   ASIANLAN 185 beginners course designed student...       REC     9-10AM
# 424   ASIANLAN 145 beginners course designed student...       REC    11-12PM
# 442   course designed spoken supplement postsecondye...       REC    11-12PM
# 3711  capstone seminar nonHonors seniors Philosophy ...       SEM    1-230PM
#
#       ... Has WL Units                                    sub_title credits  \
# 2895  ...      Y  3.00   - Contemporary Culture and Media in Turkey       3
# 3705  ...      Y  4.00                                                    4
# 1789  ...      Y  3.00                                                    3
# 234   ...      N  4.00                                                    4
# 2153  ...      Y  4.00                                                    4
# 419   ...      Y  4.00                                                    4
# 429   ...      Y  4.00                                                    4
# 424   ...      Y  4.00                                                    4
# 442   ...      Y  2.00                                                    2
# 3711  ...      Y  3.00                                                    3
#
#      requirements_distribution                         consent  \
# 2895                            With permission of instructor.
# 3705                            With permission of instructor.
# 1789
# 234                     SS, RE
# 2153                        SS
# 419                             With permission of instructor.
# 429                             With permission of instructor.
# 424                             With permission of instructor.
# 442                             With permission of instructor.
# 3711                      ULWR
#
#                                  advisory_prerequisites  \
# 2895
# 3705
# 1789                                ENVIRON 350 or 370.
# 234
# 2153
# 419
# 429
# 424
# 442
# 3711  Completion of distribution requirements for PP...
#
#                                       other_course_info  \
# 2895
# 3705
# 1789
# 234   Does not count toward requirements for the Ant...
# 2153
# 419   Students with prior knowledge of Hindi are enc...
# 429
# 424
# 442
# 3711
#
#                                           repeatability similarity_scores
# 2895  May be elected twice for credit.  May be elect...          0.346603
# 3705                    May not be repeated for credit.          0.295663
# 1789                    May not be repeated for credit.          0.291619
# 234                     May not be repeated for credit.          0.282542
# 2153                    May not be repeated for credit.          0.275862
# 419                     May not be repeated for credit.          0.268793
# 429                     May not be repeated for credit.          0.268793
# 424                     May not be repeated for credit.          0.267064
# 442                  May be elected twice for credit.            0.266815
# 3711                    May not be repeated for credit.          0.261742
#
# [10 rows x 24 columns]

# %%
make_recommendation_sk(f_21, 'AAS 103', 10)
# Out:
#       Class Nbr        course       Term                   Session  \
# 2895      37153   MIDEAST 490  Fall 2021  Regular Academic Session
# 4674      10061       URP 423  Fall 2021  Regular Academic Session
# 29        33106       AAS 495  Fall 2021  Regular Academic Session
# 3681      29772    POLSCI 436  Fall 2021  Regular Academic Session
# 1789      20075   ENVIRON 405  Fall 2021  Regular Academic Session
# 10        36353       AAS 275  Fall 2021  Regular Academic Session
# 3705      11707    PORTUG 101  Fall 2021  Regular Academic Session
# 380       32373     ASIAN 257  Fall 2021  Regular Academic Session
# 234       10647  ANTHRCUL 101  Fall 2021  Regular Academic Session
# 143       32141       ALA 421  Fall 2021     Second 7 Week Session
#
#                           Acad Group  \
# 2895   Literature, Sci, and the Arts
# 4674   Architecture & Urban Planning
# 29     Literature, Sci, and the Arts
# 3681   Literature, Sci, and the Arts
# 1789  Environment and Sustainability
# 10     Literature, Sci, and the Arts
# 3705   Literature, Sci, and the Arts
# 380    Literature, Sci, and the Arts
# 234    Literature, Sci, and the Arts
# 143    Literature, Sci, and the Arts
#
#                                                 Subject          Course Title  \
# 2895        Middle East Studies (MIDEAST) Open Sections         Topics in MES
# 4674    Urban and Regional Planning (URP) Open Sections           Int U P&Env
# 29    Afroamerican & African Studies (AAS) Open Sect...        Senior Seminar
# 3681           Political Science (POLSCI) Open Sections    ResMidEastPolitics
# 1789                Environment (ENVIRON) Open Sections          Urban Sprawl
# 10    Afroamerican & African Studies (AAS) Open Sect...    Blk Women Pop Cult
# 3705                  Portuguese (PORTUG) Open Sections            Elementary
# 380                 Asian Studies (ASIAN) Open Sections  Great Cities in Asia
# 234      Anthropology,Cultural (ANTHRCUL) Open Sections       Intro to Anthro
# 143            Applied Liberal Arts (ALA) Open Sections  Creat Inclusive Comm
#
#                                             description Component       Time  \
# 2895  This course aims to focus on analyzing popular...       SEM    1-230PM
# 4674   Introduction to Urban and Environmental Planning       DIS     12-1PM
# 29    \nThis course explores cities in contemporary ...       SEM    4-530PM
# 3681  This course will examine politics and society ...       SEM      2-4PM
# 1789  This course investigates the political imperat...       LEC  10-1130AM
# 10    Popular culture is an important site for creat...       SEM    1-230PM
# 3705  PORT101 is a highly communicative course for s...       REC    10-11AM
# 380   This course serves as an introduction to the h...       DIS     9-10AM
# 234   This course introduces students to anthropolog...       DIS      4-5PM
# 143   Residence Staff at Michigan work with resident...       SEM        ARR
#
#       ... Has WL Units                                    sub_title credits  \
# 2895  ...      Y  3.00   - Contemporary Culture and Media in Turkey       3
# 4674  ...      Y  3.00                                                    3
# 29    ...      Y  4.00          - Contemporary Africa and the World       4
# 3681  ...      N  3.00                                                    3
# 1789  ...      Y  3.00                                                    3
# 10    ...      Y  3.00                                                    3
# 3705  ...      Y  4.00                                                    4
# 380   ...      Y  4.00                                                    4
# 234   ...      N  4.00                                                    4
# 143   ...      N  1.00                                                    1
#
#      requirements_distribution                         consent  \
# 2895                            With permission of instructor.
# 4674
# 29                        ULWR
# 3681                            With permission of instructor.
# 1789
# 10                          ID
# 3705                            With permission of instructor.
# 380                         HU
# 234                     SS, RE
# 143                             With permission of instructor.
#
#      advisory_prerequisites  \
# 2895
# 4674
# 29     Upperclass standing.
# 3681
# 1789    ENVIRON 350 or 370.
# 10
# 3705
# 380
# 234
# 143
#
#                                       other_course_info  \
# 2895
# 4674
# 29                                (Cross-Area Courses).
# 3681
# 1789
# 10
# 3705
# 380
# 234   Does not count toward requirements for the Ant...
# 143
#
#                                           repeatability  \
# 2895  May be elected twice for credit.  May be elect...
# 4674                    May not be repeated for credit.
# 29      May be repeated for a maximum of 8 credit(s).
# 3681                    May not be repeated for credit.
# 1789                    May not be repeated for credit.
# 10                      May not be repeated for credit.
# 3705                    May not be repeated for credit.
# 380                  May be elected twice for credit.
# 234                     May not be repeated for credit.
# 143     May be repeated for a maximum of 4 credit(s).
#
#                       sig_scores
# 2895  (2895, 0.7615990979612387)
# 4674  (4674, 0.7615986964810271)
# 29      (29, 0.7615981538535184)
# 3681  (3681, 0.7615977222757488)
# 1789  (1789, 0.7615976026816589)
# 10       (10, 0.761597517013301)
# 3705  (3705, 0.7615975007962578)
# 380    (380, 0.7615974415269534)
# 234    (234, 0.7615972520876618)
# 143    (143, 0.7615971756555602)
#
# [10 rows x 24 columns]
