# %% [markdown]
# ## Create 5000 user profiles based on CS and LSA requirements

# %%
import pandas as pd
import pickle
import numpy as np

import numpy as np
import json
import glob

import nltk
from nltk.corpus import stopwords

from top2vec import Top2Vec

# %%
cs_students = pd.read_pickle('CS requirement/cs_students.pickle')
qr1_students = pd.read_pickle('LSA requirements/qr1_students.pickle')
qr2_students = pd.read_pickle('LSA requirements/qr2_students.pickle')

# %%
student_profiles = {}
for i in range(2500):
    student_profiles[i] = pd.concat([cs_students[i], qr1_students[i]], ignore_index=True)
    student_profiles[i+2500] = pd.concat([cs_students[i+2500], qr2_students[i]], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-31bb7c6766cc> in <module>
#       1 student_profiles = {}
#       2 for i in range(2500):
# ----> 3     student_profiles[i] = pd.concat([cs_students[i], qr1_students[i]], ignore_index=True)
#       4     student_profiles[i+2500] = pd.concat([cs_students[i+2500], qr2_students[i]], ignore_index=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     269     ValueError: Indexes have overlapping values: ['a']
#     270     """
# --> 271     op = _Concatenator(
#     272         objs,
#     273         axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     358
#     359             # consolidate
# --> 360             obj._consolidate(inplace=True)
#     361             ndims.add(obj.ndim)
#     362
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _consolidate(self, inplace)
#    5363         inplace = validate_bool_kwarg(inplace, "inplace")
#    5364         if inplace:
# -> 5365             self._consolidate_inplace()
#    5366         else:
#    5367             f = lambda: self._data.consolidate()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _consolidate_inplace(self)
#    5345             self._data = self._data.consolidate()
#    5346
# -> 5347         self._protect_consolidate(f)
#    5348
#    5349     def _consolidate(self, inplace: bool_t = False):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _protect_consolidate(self, f)
#    5333         cache
#    5334         """
# -> 5335         blocks_before = len(self._data.blocks)
#    5336         result = f()
#    5337         if len(self._data.blocks) != blocks_before:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'DataFrame' object has no attribute '_data'

# %%
student_profiles[0]

# %%
pickle.dump(student_profiles, open("student_profiles.pickle", "wb"))

# %%
f_21 = pd.read_csv('LSA requirements/f_21_merge.csv')
w_22 = pd.read_csv('LSA requirements/w_22_merge.csv')

# %%
df = pd.concat([f_21, w_22])

# %%
df.head()
# Out:
#    Class Nbr   course       Term                   Session  \
# 0      30282  AAS 103  Fall 2021  Regular Academic Session
# 1      30282  AAS 103  Fall 2021  Regular Academic Session
# 2      30282  AAS 103  Fall 2021  Regular Academic Session
# 3      30276  AAS 104  Fall 2021  Regular Academic Session
# 4      30276  AAS 104  Fall 2021  Regular Academic Session
#
#                       Acad Group  \
# 0  Literature, Sci, and the Arts
# 1  Literature, Sci, and the Arts
# 2  Literature, Sci, and the Arts
# 3  Literature, Sci, and the Arts
# 4  Literature, Sci, and the Arts
#
#                                              Subject        Course Title  \
# 0  Afroamerican & African Studies (AAS) Open Sect...  Social Sci Seminar
# 1  Afroamerican & African Studies (AAS) Open Sect...  Social Sci Seminar
# 2  Afroamerican & African Studies (AAS) Open Sect...  Social Sci Seminar
# 3  Afroamerican & African Studies (AAS) Open Sect...  Humanities Seminar
# 4  Afroamerican & African Studies (AAS) Open Sect...  Humanities Seminar
#
#                                          description Component      Time  ...  \
# 0  This course seeks to introduce students to eve...       SEM   1-230PM  ...
# 1  Blood diamonds. Resource curse. Land grabs. Th...       SEM   1-230PM  ...
# 2  This course will examine the history of racial...       SEM   1-230PM  ...
# 3  This seminar introduces first-year students to...       SEM  1130-1PM  ...
# 4  This seminar introduces first-year students to...       SEM  1130-1PM  ...
#
#   Seats Remaining Has WL Units  \
# 0               1      Y  3.00
# 1               1      Y  3.00
# 2               1      Y  3.00
# 3               2      Y  3.00
# 4               2      Y  3.00
#
#                                            sub_title credits  \
# 0   - Reading Africa: Critical Perspectives on Po...       3
# 1               - Reconsidering African Environments       3
# 2        - South Africa: from Apartheid to Democracy       3
# 3   - Black Lives and Life Writing: How We Tell S...       3
# 4                          - Black Atlantic Religion       3
#
#   requirements_distribution                         consent  \
# 0                        SS                             NaN
# 1                        SS                             NaN
# 2                        SS                             NaN
# 3                        HU  With permission of instructor.
# 4                        HU                             NaN
#
#                               advisory_prerequisites  \
# 0  Enrollment restricted to first-year students, ...
# 1  Enrollment restricted to first-year students, ...
# 2  Enrollment restricted to first-year students, ...
# 3  Enrollment restricted to first-year students, ...
# 4  Enrollment restricted to first-year students, ...
#
#                                    other_course_info  \
# 0  (Cross-Area Courses). May not be included in a...
# 1  (Cross-Area Courses). May not be included in a...
# 2  (Cross-Area Courses). May not be included in a...
# 3  (Cross-Area Courses). May not be included in a...
# 4  (Cross-Area Courses). May not be included in a...
#
#                      repeatability
# 0  May not be repeated for credit.
# 1  May not be repeated for credit.
# 2  May not be repeated for credit.
# 3  May not be repeated for credit.
# 4  May not be repeated for credit.
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Class Nbr', 'course', 'Term', 'Session', 'Acad Group', 'Subject',
#        'Course Title', 'description', 'Component', 'Time', 'Location',
#        'Instructor', 'Total', 'Seats Remaining', 'Has WL', 'Units',
#        'sub_title', 'credits', 'requirements_distribution', 'consent',
#        'advisory_prerequisites', 'other_course_info', 'repeatability'],
#       dtype='object')

# %%
df['course_full_text'] = df['Course Title'] + df['sub_title'] + df['description'] + df['Acad Group'] + df['Subject']

# %%
len(df)
# Out:
# 105035

# %%
df.dropna(subset=['course_full_text'], inplace=True)

# %%
df.reset_index(inplace=True)

# %%
texts = df.course_full_text.tolist()

# %%
len(texts)
# Out:
# 7605

# %%
model = Top2Vec(texts, embedding_model='universal-sentence-encoder', min_count=5, speed='learn', workers=8)
# Out:
# 2021-11-28 13:09:51,997 - top2vec - INFO - Pre-processing documents for training
# INFO:top2vec:Pre-processing documents for training
# 2021-11-28 13:09:55,126 - top2vec - INFO - Downloading universal-sentence-encoder model
# INFO:top2vec:Downloading universal-sentence-encoder model
# 2021-11-28 13:10:19,143 - top2vec - INFO - Creating joint document/word embedding
# INFO:top2vec:Creating joint document/word embedding
# 2021-11-28 13:10:22,891 - top2vec - INFO - Creating lower dimension embedding of documents
# INFO:top2vec:Creating lower dimension embedding of documents
# 2021-11-28 13:10:51,549 - top2vec - INFO - Finding dense areas of documents
# INFO:top2vec:Finding dense areas of documents
# 2021-11-28 13:10:51,726 - top2vec - INFO - Finding topics
# INFO:top2vec:Finding topics

# %%
model.save('course_topics_model')

# %%
model.get_num_topics()
# Out:
# 134

# %%
topic_sizes, topic_nums = model.get_topic_sizes()

# %%
topic_words, word_scores, topic_nums = model.get_topics(134)

# %%
topic_words[0]
# Out:
# array(['dances', 'dance', 'dancing', 'ballet', 'dancers', 'genres',
#        'rhythms', 'rhythm', 'lyrical', 'sufism', 'improvisation',
#        'modernism', 'clases', 'jazz', 'rhythmic', 'modernist', 'clase',
#        'genre', 'genderqueer', 'judicial', 'segregation', 'encompasses',
#        'harlem', 'flexibility', 'sociology', 'principles', 'syllabus',
#        'estudio', 'hip', 'artform', 'antebellum', 'workshops',
#        'rehearsals', 'composing', 'counterculture', 'hop', 'thriller',
#        'sociologists', 'grapple', 'grappling', 'allowed', 'composition',
#        'yoga', 'justices', 'motown', 'attending', 'classes', 'cabaret',
#        'tempo', 'collectively'], dtype='<U15')

# %%
documents, document_scores, document_ids = model.search_documents_by_topic(topic_num=0, num_docs=1)

# %%
document_ids_list = []
topic_list = []

for topic_num in topic_nums:
    documents, document_scores, document_ids = model.search_documents_by_topic(topic_num=topic_num, num_docs=5)
    document_ids_list.append(document_ids)
    topic_list.append(topic_num)

# %%
topic_df = pd.DataFrame(zip(document_ids_list, topic_list), columns=['document_id', 'topic_num'])

# %%
topic_df
# Out:
#                         document_id  topic_num
# 0    [3757, 3551, 3549, 3548, 3547]          0
# 1      [846, 1098, 1154, 912, 1088]          1
# 2    [6433, 6541, 6517, 6527, 6528]          2
# 3    [2608, 2708, 2670, 6629, 2672]          3
# 4    [6499, 6498, 6534, 6511, 6514]          4
# ..                              ...        ...
# 129  [1783, 1780, 1789, 1786, 1777]        129
# 130  [5445, 5443, 5435, 5433, 5431]        130
# 131  [1700, 1691, 1683, 1675, 1667]        131
# 132  [3358, 3346, 3334, 3322, 3310]        132
# 133  [3180, 3176, 3168, 3172, 3164]        133
#
# [134 rows x 2 columns]

# %%
df
# Out:
#       index  Class Nbr       course         Term                   Session  \
# 0         0      30282      AAS 103    Fall 2021  Regular Academic Session
# 1         1      30282      AAS 103    Fall 2021  Regular Academic Session
# 2         2      30282      AAS 103    Fall 2021  Regular Academic Session
# 3         3      30276      AAS 104    Fall 2021  Regular Academic Session
# 4         4      30276      AAS 104    Fall 2021  Regular Academic Session
# ...     ...        ...          ...          ...                       ...
# 7600  74516      37099  WRITING 201  Winter 2022      First 7 Week Session
# 7601  74517      37099  WRITING 201  Winter 2022      First 7 Week Session
# 7602  74518      37099  WRITING 201  Winter 2022      First 7 Week Session
# 7603  74526      27799  WRITING 405  Winter 2022  Regular Academic Session
# 7604  74527      23672  WRITING 410  Winter 2022  Regular Academic Session
#
#                          Acad Group  \
# 0     Literature, Sci, and the Arts
# 1     Literature, Sci, and the Arts
# 2     Literature, Sci, and the Arts
# 3     Literature, Sci, and the Arts
# 4     Literature, Sci, and the Arts
# ...                             ...
# 7600  Literature, Sci, and the Arts
# 7601  Literature, Sci, and the Arts
# 7602  Literature, Sci, and the Arts
# 7603  Literature, Sci, and the Arts
# 7604  Literature, Sci, and the Arts
#
#                                                 Subject          Course Title  \
# 0     Afroamerican & African Studies (AAS) Open Sect...    Social Sci Seminar
# 1     Afroamerican & African Studies (AAS) Open Sect...    Social Sci Seminar
# 2     Afroamerican & African Studies (AAS) Open Sect...    Social Sci Seminar
# 3     Afroamerican & African Studies (AAS) Open Sect...    Humanities Seminar
# 4     Afroamerican & African Studies (AAS) Open Sect...    Humanities Seminar
# ...                                                 ...                   ...
# 7600  Gayle Morris Sweetland Center for Writing (WRI...   Dig Media Wrtg Mini
# 7601  Gayle Morris Sweetland Center for Writing (WRI...   Dig Media Wrtg Mini
# 7602  Gayle Morris Sweetland Center for Writing (WRI...   Dig Media Wrtg Mini
# 7603  Gayle Morris Sweetland Center for Writing (WRI...   Contemporary Topics
# 7604  Gayle Morris Sweetland Center for Writing (WRI...  Quant Analys & Wrtng
#
#                                             description Component  ... Has WL  \
# 0     This course seeks to introduce students to eve...       SEM  ...      Y
# 1     Blood diamonds. Resource curse. Land grabs. Th...       SEM  ...      Y
# 2     This course will examine the history of racial...       SEM  ...      Y
# 3     This seminar introduces first-year students to...       SEM  ...      Y
# 4     This seminar introduces first-year students to...       SEM  ...      Y
# ...                                                 ...       ...  ...    ...
# 7600  A well-designed infographic can capture a read...       SEM  ...      N
# 7601  Are you a visual artist, slam poet, performer,...       SEM  ...      N
# 7602  Do you love stories, especially getting other ...       SEM  ...      N
# 7603  This class focuses on how writing works in and...       SEM  ...      Y
# 7604  “The human right to water is indispensable for...       SEM  ...      Y
#
#      Units                                          sub_title credits  \
# 0     3.00   - Reading Africa: Critical Perspectives on Po...       3
# 1     3.00               - Reconsidering African Environments       3
# 2     3.00        - South Africa: from Apartheid to Democracy       3
# 3     3.00   - Black Lives and Life Writing: How We Tell S...       3
# 4     3.00                          - Black Atlantic Religion       3
# ...    ...                                                ...     ...
# 7600  1.00                     - The Rhetoric of Infographics       1
# 7601  1.00                       - Digital Media and the Arts       1
# 7602  1.00                               - Collecting Stories       1
# 7603  3.00   - Everything Matters: How to Integrate Everyt...       3
# 7604  3.00                       - Understanding Water Crises       3
#
#      requirements_distribution                         consent  \
# 0                           SS                             NaN
# 1                           SS                             NaN
# 2                           SS                             NaN
# 3                           HU  With permission of instructor.
# 4                           HU                             NaN
# ...                        ...                             ...
# 7600                       NaN                             NaN
# 7601                       NaN                             NaN
# 7602                       NaN                             NaN
# 7603                      ULWR                             NaN
# 7604                ULWR, QR/2                             NaN
#
#                                  advisory_prerequisites  \
# 0     Enrollment restricted to first-year students, ...
# 1     Enrollment restricted to first-year students, ...
# 2     Enrollment restricted to first-year students, ...
# 3     Enrollment restricted to first-year students, ...
# 4     Enrollment restricted to first-year students, ...
# ...                                                 ...
# 7600                                                NaN
# 7601                                                NaN
# 7602                                                NaN
# 7603         First Year Writing Requirement encouraged.
# 7604  Completion of the First-Year Writing Requirement.
#
#                                       other_course_info  \
# 0     (Cross-Area Courses). May not be included in a...
# 1     (Cross-Area Courses). May not be included in a...
# 2     (Cross-Area Courses). May not be included in a...
# 3     (Cross-Area Courses). May not be included in a...
# 4     (Cross-Area Courses). May not be included in a...
# ...                                                 ...
# 7600                                                NaN
# 7601                                                NaN
# 7602                                                NaN
# 7603                                                NaN
# 7604                                                NaN
#
#                                           repeatability  \
# 0                       May not be repeated for credit.
# 1                       May not be repeated for credit.
# 2                       May not be repeated for credit.
# 3                       May not be repeated for credit.
# 4                       May not be repeated for credit.
# ...                                                 ...
# 7600  May be elected three times for credit.  May be...
# 7601  May be elected three times for credit.  May be...
# 7602  May be elected three times for credit.  May be...
# 7603                    May not be repeated for credit.
# 7604    May be repeated for a maximum of 6 credit(s).
#
#                                        course_full_text
# 0     Social Sci Seminar - Reading Africa: Critical ...
# 1     Social Sci Seminar - Reconsidering African Env...
# 2     Social Sci Seminar - South Africa: from Aparth...
# 3     Humanities Seminar - Black Lives and Life Writ...
# 4     Humanities Seminar - Black Atlantic ReligionTh...
# ...                                                 ...
# 7600  Dig Media Wrtg Mini - The Rhetoric of Infograp...
# 7601  Dig Media Wrtg Mini - Digital Media and the Ar...
# 7602  Dig Media Wrtg Mini - Collecting StoriesDo you...
# 7603  Contemporary Topics - Everything Matters: How ...
# 7604  Quant Analys & Wrtng - Understanding Water Cri...
#
# [7605 rows x 25 columns]
